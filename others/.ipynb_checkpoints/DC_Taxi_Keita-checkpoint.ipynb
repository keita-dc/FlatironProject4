# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
# %matplotlib inline
plt.style.use("seaborn")
sns.set_context("talk")

# %%
df = pd.read_csv("../data/Taxicab_Trips_Sampling_in_July_2017.csv")

# %%
df.drop_duplicates(inplace=True)
df = df.loc[df.TOTALAMOUNT>0]
df = df.loc[df.TOTALAMOUNT<1000]
df = df.loc[df.METERFARE>0]
df = df.loc[df.TRIPMILEAGE>0]
df = df.loc[df.TRIPMILEAGE<100]
df = df.loc[df.TRIPTIME>0]
df = df.loc[df.TRIPTIME<120]
df = df.loc[df.TRIPMILEAGE/df.TRIPTIME<2]
df.AIRPORT = df.AIRPORT == "Y"
df["pickup_quadrant"] = df.PICKUP_BLOCKNAME.str.extract(r"\s([NS][EW])\b")
df["dropoff_quadrant"] = df.DROPOFF_BLOCKNAME.str.extract(r"\s([NS][EW])\b")
df["tipping"] = (df.TIP>0) * 1 

df['pickup_datetime'] = pd.to_datetime(df.PICKUPDATETIME_TR)
df['dropoff_datetime'] = pd.to_datetime(df.DROPOFFDATETIME_TR)
df['pickup_date'] = df.pickup_datetime.dt.date
df['pickup_hour'] = df.pickup_datetime.dt.hour
df['dropoff_date'] = df.dropoff_datetime.dt.date
df['dropoff_hour'] = df.dropoff_datetime.dt.hour

df = df.drop(["OBJECTID_1", "OBJECTID"], axis=1)

# %%
df.loc[df.DROPOFFSTATE=="Virgin Islands", "DROPOFFSTATE"] = "Virginia"
df.loc[df.PICKUPSTATE=="Virgin Islands", "PICKUPSTATE"] = "Virginia"
df.loc[df.DROPOFFSTATE=="Washington", "DROPOFFSTATE"] = "District of Columbia"
df.loc[df.PICKUPSTATE=="Washington", "PICKUPSTATE"] = "District of Columbia"
df.loc[df.PAYMENTCARDPROVIDER=="Unknown = 0", "PAYMENTCARDPROVIDER"] = np.nan

# %%
df.shape
# Out:
# (201887, 36)

# %%
df.shape
# Out:
# (201887, 36)

# %%
df.head()
# Out:
#   TRIPTYPE       PROVIDER  METERFARE   TIP  SURCHARGE  EXTRAS  TOLLS  \
# 0      PSP  Transco, Inc.       3.52  0.00       0.25   21.75    0.0
# 1      PSP  Transco, Inc.       5.14  0.00       0.25    0.00    0.0
# 2      PSP  Transco, Inc.      14.32  4.67       0.25    1.00    0.0
# 3      PSP  Transco, Inc.       4.33  1.12       0.25    1.00    0.0
# 4      PSP  Transco, Inc.      11.89  0.00       0.25    1.00    0.0
#
#    TOTALAMOUNT PAYMENTTYPE PAYMENTCARDPROVIDER  ...        DROPOFFDATETIME_TR  \
# 0        25.52  CreditCard          VisaCredit  ...  2017-07-28T18:00:00.000Z
# 1         5.39        Cash                Cash  ...  2017-07-28T18:00:00.000Z
# 2        20.24  CreditCard    MasterCardCredit  ...  2017-07-28T19:00:00.000Z
# 3         6.70  CreditCard    MasterCardCredit  ...  2017-07-28T19:00:00.000Z
# 4        13.14        Cash                Cash  ...  2017-07-29T15:00:00.000Z
#
#   pickup_quadrant dropoff_quadrant tipping           pickup_datetime  \
# 0              NE               NE       0 2017-07-28 18:00:00+00:00
# 1              NE               NE       0 2017-07-28 18:00:00+00:00
# 2              SW               NW       1 2017-07-28 19:00:00+00:00
# 3              NW               NW       1 2017-07-28 19:00:00+00:00
# 4              NW               NW       0 2017-07-29 14:00:00+00:00
#
#            dropoff_datetime  pickup_date  pickup_hour  dropoff_date  \
# 0 2017-07-28 18:00:00+00:00   2017-07-28           18    2017-07-28
# 1 2017-07-28 18:00:00+00:00   2017-07-28           18    2017-07-28
# 2 2017-07-28 19:00:00+00:00   2017-07-28           19    2017-07-28
# 3 2017-07-28 19:00:00+00:00   2017-07-28           19    2017-07-28
# 4 2017-07-29 15:00:00+00:00   2017-07-29           14    2017-07-29
#
#    dropoff_hour
# 0            18
# 1            18
# 2            19
# 3            19
# 4            15
#
# [5 rows x 36 columns]

# %%
df.columns
# Out:
# Index(['TRIPTYPE', 'PROVIDER', 'METERFARE', 'TIP', 'SURCHARGE', 'EXTRAS',
#        'TOLLS', 'TOTALAMOUNT', 'PAYMENTTYPE', 'PAYMENTCARDPROVIDER',
#        'PICKUPCITY', 'PICKUPSTATE', 'PICKUPZIP', 'DROPOFFCITY', 'DROPOFFSTATE',
#        'DROPOFFZIP', 'TRIPMILEAGE', 'TRIPTIME', 'PICKUP_BLOCK_LATITUDE',
#        'PICKUP_BLOCK_LONGITUDE', 'PICKUP_BLOCKNAME', 'DROPOFF_BLOCK_LATITUDE',
#        'DROPOFF_BLOCK_LONGITUDE', 'DROPOFF_BLOCKNAME', 'AIRPORT',
#        'PICKUPDATETIME_TR', 'DROPOFFDATETIME_TR', 'pickup_quadrant',
#        'dropoff_quadrant', 'tipping', 'pickup_datetime', 'dropoff_datetime',
#        'pickup_date', 'pickup_hour', 'dropoff_date', 'dropoff_hour'],
#       dtype='object')

# %%
df.describe()
# Out:
#            METERFARE            TIP      SURCHARGE         EXTRAS  \
# count  196493.000000  196493.000000  196493.000000  196493.000000
# mean       12.276120       1.343199       0.249834       0.651913
# std         9.046264       2.229697       0.020427       1.011364
# min         1.000000       0.000000       0.000000      -0.250000
# 25%         7.300000       0.000000       0.250000       0.000000
# 50%        10.000000       0.000000       0.250000       0.000000
# 75%        14.320000       2.200000       0.250000       1.000000
# max       223.840000     300.000000       8.720000      49.750000
#
#                TOLLS    TOTALAMOUNT    TRIPMILEAGE       TRIPTIME  \
# count  196493.000000  196493.000000  196493.000000  196493.000000
# mean        0.001160      14.544993       3.223002      13.804273
# std         0.099937      10.229420       4.258935       9.339627
# min         0.000000       3.250000       0.010000       1.000000
# 25%         0.000000       8.900000       1.000000       8.000000
# 50%         0.000000      11.870000       2.000000      12.000000
# 75%         0.000000      17.000000       3.900000      17.000000
# max        33.000000     316.650000      95.430000     119.000000
#
#        PICKUP_BLOCK_LATITUDE  PICKUP_BLOCK_LONGITUDE  DROPOFF_BLOCK_LATITUDE  \
# count          170525.000000           170525.000000           156706.000000
# mean               38.902861              -77.029643               38.904968
# std                 0.015047                0.018872                0.016947
# min                38.814661              -77.112057               38.814661
# 25%                38.895463              -77.041860               38.896039
# 50%                38.900480              -77.031943               38.902516
# 75%                38.906600              -77.018731               38.910753
# max                38.991518              -76.911744               38.991518
#
#        DROPOFF_BLOCK_LONGITUDE        tipping    pickup_hour   dropoff_hour
# count            156706.000000  196493.000000  196493.000000  196493.000000
# mean                -77.029730       0.453996      13.920221      14.008845
# std                   0.021450       0.497880       5.324881       5.384487
# min                 -77.113633       0.000000       0.000000       0.000000
# 25%                 -77.042604       0.000000      11.000000      11.000000
# 50%                 -77.031140       0.000000      14.000000      14.000000
# 75%                 -77.017201       1.000000      18.000000      18.000000
# max                 -76.910927       1.000000      23.000000      23.000000

# %%
plt.figure(figsize=(10,11))
plt.scatter(df.loc[df.tipping==1].PICKUP_BLOCK_LONGITUDE,
            df.loc[df.tipping==1].PICKUP_BLOCK_LATITUDE, 
            alpha=0.02, 
            s=5,
            c="blue")
plt.scatter(df.loc[df.tipping==0].PICKUP_BLOCK_LONGITUDE,
            df.loc[df.tipping==0].PICKUP_BLOCK_LATITUDE,
            alpha=0.02,
            s=5,
            c="orange" )
plt.xlim(-77.12, -76.90)
plt.ylim(38.80, 39.00)
# Out:
# (38.8, 39.0)

# %%
plt.figure(figsize=(10,11))
plt.scatter(df.loc[df.tipping==1].PICKUP_BLOCK_LONGITUDE,
            df.loc[df.tipping==1].PICKUP_BLOCK_LATITUDE, 
            alpha=0.05, 
            s=5,
            c="blue")
plt.xlim(-77.12, -76.90)
plt.ylim(38.80, 39.00)
# Out:
# (38.8, 39.0)

# %%
plt.figure(figsize=(10,11))
plt.scatter(df.loc[df.tipping==0].PICKUP_BLOCK_LONGITUDE,
            df.loc[df.tipping==0].PICKUP_BLOCK_LATITUDE,
            alpha=0.05,
            s=5,
            c="orange" )
plt.xlim(-77.12, -76.90)
plt.ylim(38.80, 39.00)
# Out:
# (38.8, 39.0)

# %%
plt.figure(figsize=(10, 10.25))

plt.scatter(df.loc[df.tipping==0].DROPOFF_BLOCK_LONGITUDE,
            df.loc[df.tipping==0].DROPOFF_BLOCK_LATITUDE,
            alpha=0.05,
            s=0.5,
            c="gold")
plt.scatter(df.loc[df.tipping==1].DROPOFF_BLOCK_LONGITUDE,
            df.loc[df.tipping==1].DROPOFF_BLOCK_LATITUDE, 
            alpha=0.05, 
            s=0.5,
            c="blue")

plt.xlim(-77.12, -76.90)
plt.ylim(38.80, 39.00)
plt.title("Tipping & Non-Tipping")
plt.legend(["Tipping (blue)", "No-Tipping (yellow)"], loc=4)

plt.xlabel("Longitude")
plt.xticks([-77.1, -77, -76.9])
plt.ylabel("Latitude")
plt.yticks([38.8, 38.9, 39])
plt.tight_layout()
plt.savefig("../image/tipping_map_large")
plt.show()

# %%
plt.figure(figsize=(10,11))
plt.scatter(df.loc[df.tipping==1].DROPOFF_BLOCK_LONGITUDE,
            df.loc[df.tipping==1].DROPOFF_BLOCK_LATITUDE, 
            alpha=0.05, 
            s=5,
            c="blue")
plt.xlim(-77.12, -76.90)
plt.ylim(38.80, 39.00)
# Out:
# (38.8, 39.0)

# %%
plt.figure(figsize=(10,11))
plt.scatter(df.loc[df.tipping==0].DROPOFF_BLOCK_LONGITUDE,
            df.loc[df.tipping==0].DROPOFF_BLOCK_LATITUDE,
            alpha=0.05,
            s=5,
            c="orange" )
plt.xlim(-77.12, -76.90)
plt.ylim(38.80, 39.00)
# Out:
# (38.8, 39.0)

# %%
df["distance_capitol"] = np.sqrt((df.DROPOFF_BLOCK_LATITUDE-38.8899)**2
                                 +(df.DROPOFF_BLOCK_LONGITUDE+77.0091)**2)

# %%
df.TRIPTYPE.value_counts()
# Out:
# PSP             193798
# TRANSPORT-DC      1352
# DDS               1343
# Name: TRIPTYPE, dtype: int64

# %%
df.groupby(["TRIPTYPE", "PROVIDER"]).tipping.describe()
# Out:
#                                  count      mean       std  min  25%  50%  \
# TRIPTYPE     PROVIDER
# DDS          DCVIP Cab            12.0  0.833333  0.389249  0.0  1.0  1.0
#              United Ventures    1331.0  0.812923  0.390120  0.0  1.0  1.0
# PSP          CMT               39746.0  0.534897  0.498787  0.0  0.0  1.0
#              DCVIP Cab         26097.0  0.721730  0.448155  0.0  0.0  1.0
#              Hitch             28700.0  0.000418  0.020444  0.0  0.0  0.0
#              My Taxi Control    2140.0  0.433645  0.495693  0.0  0.0  0.0
#              Transco, Inc.     25509.0  0.442824  0.496730  0.0  0.0  0.0
#              United Ventures   28840.0  0.539528  0.498444  0.0  0.0  1.0
#              Verifone          26682.0  0.509594  0.499917  0.0  0.0  1.0
#              Yellow Cab of DC  16084.0  0.411900  0.492192  0.0  0.0  0.0
# TRANSPORT-DC Yellow Cab of DC   1352.0  0.001479  0.038447  0.0  0.0  0.0
#
#                                75%  max
# TRIPTYPE     PROVIDER
# DDS          DCVIP Cab         1.0  1.0
#              United Ventures   1.0  1.0
# PSP          CMT               1.0  1.0
#              DCVIP Cab         1.0  1.0
#              Hitch             0.0  1.0
#              My Taxi Control   1.0  1.0
#              Transco, Inc.     1.0  1.0
#              United Ventures   1.0  1.0
#              Verifone          1.0  1.0
#              Yellow Cab of DC  1.0  1.0
# TRANSPORT-DC Yellow Cab of DC  0.0  1.0

# %%
df["tip_ratio"] = df.TIP / df.METERFARE
df.groupby(["TRIPTYPE", "PROVIDER"]).tip_ratio.describe()
# Out:
#                                  count      mean       std  min       25%  \
# TRIPTYPE     PROVIDER
# DDS          DCVIP Cab            12.0  0.216145  0.202886  0.0  0.053765
#              United Ventures    1331.0  0.206220  0.130244  0.0  0.154083
# PSP          CMT               39746.0  0.136007  0.152885  0.0  0.000000
#              DCVIP Cab         26097.0  0.279013  0.459057  0.0  0.000000
#              Hitch             28700.0  0.000097  0.004976  0.0  0.000000
#              My Taxi Control    2140.0  0.101662  0.130620  0.0  0.000000
#              Transco, Inc.     25509.0  0.108932  0.148928  0.0  0.000000
#              United Ventures   28840.0  0.134234  0.151147  0.0  0.000000
#              Verifone          26682.0  0.127429  0.147287  0.0  0.000000
#              Yellow Cab of DC  16084.0  0.105266  0.147407  0.0  0.000000
# TRANSPORT-DC Yellow Cab of DC   1352.0  0.000251  0.007045  0.0  0.000000
#
#                                     50%       75%        max
# TRIPTYPE     PROVIDER
# DDS          DCVIP Cab         0.206242  0.281736   0.615385
#              United Ventures   0.229890  0.260498   1.540832
# PSP          CMT               0.127551  0.238663   5.206654
#              DCVIP Cab         0.224215  0.336323  28.230769
#              Hitch             0.000000  0.000000   0.382653
#              My Taxi Control   0.000000  0.204344   0.841043
#              Transco, Inc.     0.000000  0.212606   6.538462
#              United Ventures   0.127632  0.231214   4.106776
#              Verifone          0.105708  0.227578   3.557692
#              Yellow Cab of DC  0.000000  0.205550   2.469136
# TRANSPORT-DC Yellow Cab of DC  0.000000  0.000000   0.239044

# %%
df.sort_values(by="TOTALAMOUNT", ascending=False).head()
# Out:
#        TRIPTYPE          PROVIDER  METERFARE     TIP  SURCHARGE  EXTRAS  \
# 224035      PSP         DCVIP Cab      15.40  300.00       0.25    1.00
# 95599       PSP   United Ventures     223.84   48.02       0.25    1.00
# 22649       PSP         DCVIP Cab     192.52   40.00       0.25    3.00
# 202746      PSP  Yellow Cab of DC     145.81   88.00       0.25    0.25
# 55840       PSP         DCVIP Cab      14.86  189.00       0.25    0.00
#
#         TOLLS  TOTALAMOUNT PAYMENTTYPE PAYMENTCARDPROVIDER  ...  \
# 224035    0.0       316.65  CreditCard          VisaCredit  ...
# 95599    15.0       288.11  CreditCard          VisaCredit  ...
# 22649     0.0       235.77  CreditCard    MasterCardCredit  ...
# 202746    0.0       234.06        Cash                Cash  ...
# 55840     0.0       204.11        Cash                Cash  ...
#
#        dropoff_quadrant tipping           pickup_datetime  \
# 224035               SW       1 2017-07-26 17:00:00+00:00
# 95599               NaN       1 2017-07-24 08:00:00+00:00
# 22649               NaN       1 2017-07-23 00:00:00+00:00
# 202746               NW       1 2017-07-24 14:00:00+00:00
# 55840                NW       1 2017-07-26 09:00:00+00:00
#
#                 dropoff_datetime pickup_date pickup_hour  dropoff_date  \
# 224035 2017-07-26 17:00:00+00:00  2017-07-26          17    2017-07-26
# 95599  2017-07-24 11:00:00+00:00  2017-07-24           8    2017-07-24
# 22649  2017-07-23 01:00:00+00:00  2017-07-23           0    2017-07-23
# 202746 2017-07-24 14:00:00+00:00  2017-07-24          14    2017-07-24
# 55840  2017-07-26 09:00:00+00:00  2017-07-26           9    2017-07-26
#
#         dropoff_hour  distance_capitol  tip_ratio
# 224035            17          0.002758  19.480519
# 95599             11               NaN   0.214528
# 22649              1               NaN   0.207771
# 202746            14          0.047261   0.603525
# 55840              9          0.027123  12.718708
#
# [5 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 196493 entries, 0 to 228610
# Data columns (total 38 columns):
# TRIPTYPE                   196493 non-null object
# PROVIDER                   196493 non-null object
# METERFARE                  196493 non-null float64
# TIP                        196493 non-null float64
# SURCHARGE                  196493 non-null float64
# EXTRAS                     196493 non-null float64
# TOLLS                      196493 non-null float64
# TOTALAMOUNT                196493 non-null float64
# PAYMENTTYPE                196493 non-null object
# PAYMENTCARDPROVIDER        196363 non-null object
# PICKUPCITY                 153213 non-null object
# PICKUPSTATE                158959 non-null object
# PICKUPZIP                  165131 non-null object
# DROPOFFCITY                142384 non-null object
# DROPOFFSTATE               158187 non-null object
# DROPOFFZIP                 164890 non-null object
# TRIPMILEAGE                196493 non-null float64
# TRIPTIME                   196493 non-null float64
# PICKUP_BLOCK_LATITUDE      170525 non-null float64
# PICKUP_BLOCK_LONGITUDE     170525 non-null float64
# PICKUP_BLOCKNAME           170525 non-null object
# DROPOFF_BLOCK_LATITUDE     156706 non-null float64
# DROPOFF_BLOCK_LONGITUDE    156706 non-null float64
# DROPOFF_BLOCKNAME          156706 non-null object
# AIRPORT                    196493 non-null bool
# PICKUPDATETIME_TR          196493 non-null object
# DROPOFFDATETIME_TR         196493 non-null object
# pickup_quadrant            168960 non-null object
# dropoff_quadrant           155050 non-null object
# tipping                    196493 non-null int64
# pickup_datetime            196493 non-null datetime64[ns, UTC]
# dropoff_datetime           196493 non-null datetime64[ns, UTC]
# pickup_date                196493 non-null object
# pickup_hour                196493 non-null int64
# dropoff_date               196493 non-null object
# dropoff_hour               196493 non-null int64
# distance_capitol           156706 non-null float64
# tip_ratio                  196493 non-null float64
# dtypes: bool(1), datetime64[ns, UTC](2), float64(14), int64(3), object(18)
# memory usage: 57.2+ MB

# %%
df.PICKUPSTATE.value_counts()
# Out:
# District of Columbia    146179
# Virginia                 10606
# Nebraska                  1274
# Maryland                   870
# Montana                     17
# Connecticut                 10
# Delaware                     2
# Indiana                      1
# Name: PICKUPSTATE, dtype: int64

# %%
df.pickup_date.min()
# Out:
# datetime.date(2017, 7, 23)

# %%
list(range(23, 31))
# Out:
# [23, 24, 25, 26, 27, 28, 29, 30]

# %%
df.pickup_datetime.hist(bins=168)
plt.xlabel("Date")
plt.ylabel("Count per Hour")
plt.title("Taxi Trips in DC")
#plt.xticks(labels=list(range(23, 31)))
# Out:
# /Users/kmiyaki/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Taxi Trips in DC')

# %%
formula = "TOTALAMOUNT ~ TRIPMILEAGE + TRIPTIME"
model = smf.ols(formula, df).fit(cov_type="HC1")
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            TOTALAMOUNT   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                 5.219e+04
# Date:                Tue, 30 Jul 2019   Prob (F-statistic):               0.00
# Time:                        17:56:17   Log-Likelihood:            -5.3017e+05
# No. Observations:              196493   AIC:                         1.060e+06
# Df Residuals:                  196490   BIC:                         1.060e+06
# Df Model:                           2
# Covariance Type:                  HC1
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       4.7696      0.033    142.378      0.000       4.704       4.835
# TRIPMILEAGE     1.7645      0.012    143.405      0.000       1.740       1.789
# TRIPTIME        0.2962      0.004     70.684      0.000       0.288       0.304
# ==============================================================================
# Omnibus:                   208990.307   Durbin-Watson:                   1.661
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1038035809.413
# Skew:                           4.028   Prob(JB):                         0.00
# Kurtosis:                     358.981   Cond. No.                         31.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """

# %%
formula = "METERFARE ~ TRIPMILEAGE"
model = smf.ols(formula, df).fit(cov_type="HC1")
model.summary()

plt.rc('figure', figsize=(8, 5))
plt.text(0.01, 0.05, str(model.summary()), {'fontsize': 10}, fontproperties = 'monospace') # approach improved by OP -> monospace!
plt.axis('off')
plt.tight_layout()
plt.savefig('image/ols_meterfare_tripmileage')

# %%
plt.figure(figsize=(4.8, 3.6))
plt.scatter(df.TRIPMILEAGE, 
            df.METERFARE, 
            s=5, 
            alpha=0.6)
plt.xlabel("Mileage")
plt.ylabel("Meterfare")
plt.title("Mileage and Meterfare")
plt.tight_layout()
plt.savefig("image/meterfare_all")
plt.show()

# %%
plt.figure(figsize=(4.8, 3.6))
plt.scatter(df.loc[df.PROVIDER=="Yellow Cab of DC"].TRIPMILEAGE, 
            df.loc[df.PROVIDER=="Yellow Cab of DC"].METERFARE, 
            s=5, 
            alpha=0.8,
            c = "gold")
plt.scatter(df.loc[df.PROVIDER!="Yellow Cab of DC"].TRIPMILEAGE, 
            df.loc[df.PROVIDER!="Yellow Cab of DC"].METERFARE, 
            s=5, 
            alpha=0.6)
plt.xlabel("Mileage")
plt.ylabel("Meterfare")
plt.title("Mileage & Fare: Yellow Cab/Other")
plt.legend(["Yellow Cab", "Others"])
plt.tight_layout()
plt.savefig("image/meterfare_yellowcab")
plt.show()

# %%
formula = "METERFARE ~ TRIPMILEAGE * C(PROVIDER)"
model = smf.ols(formula, df).fit(cov_type="HC1")
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              METERFARE   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                 2.584e+04
# Date:                Tue, 30 Jul 2019   Prob (F-statistic):               0.00
# Time:                        17:56:34   Log-Likelihood:            -4.7066e+05
# No. Observations:              196493   AIC:                         9.414e+05
# Df Residuals:                  196477   BIC:                         9.415e+05
# Df Model:                          15
# Covariance Type:                  HC1
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       5.4009      0.023    239.593      0.000       5.357       5.445
# C(PROVIDER)[T.DCVIP Cab]                       -0.6824      0.039    -17.380      0.000      -0.759      -0.605
# C(PROVIDER)[T.Hitch]                            0.6971      0.039     17.956      0.000       0.621       0.773
# C(PROVIDER)[T.My Taxi Control]                  0.2530      0.105      2.413      0.016       0.048       0.459
# C(PROVIDER)[T.Transco, Inc.]                    0.0078      0.091      0.086      0.931      -0.170       0.185
# C(PROVIDER)[T.United Ventures]                 -0.0621      0.028     -2.181      0.029      -0.118      -0.006
# C(PROVIDER)[T.Verifone]                         0.0334      0.050      0.671      0.502      -0.064       0.131
# C(PROVIDER)[T.Yellow Cab of DC]                 0.5646      0.040     14.021      0.000       0.486       0.644
# TRIPMILEAGE                                     2.2176      0.008    273.257      0.000       2.202       2.234
# TRIPMILEAGE:C(PROVIDER)[T.DCVIP Cab]           -0.0117      0.015     -0.782      0.434      -0.041       0.018
# TRIPMILEAGE:C(PROVIDER)[T.Hitch]                0.1966      0.014     14.077      0.000       0.169       0.224
# TRIPMILEAGE:C(PROVIDER)[T.My Taxi Control]      0.0702      0.031      2.267      0.023       0.010       0.131
# TRIPMILEAGE:C(PROVIDER)[T.Transco, Inc.]        0.0040      0.032      0.125      0.900      -0.059       0.067
# TRIPMILEAGE:C(PROVIDER)[T.United Ventures]     -0.0039      0.010     -0.389      0.697      -0.023       0.016
# TRIPMILEAGE:C(PROVIDER)[T.Verifone]            -0.0075      0.019     -0.400      0.690      -0.044       0.029
# TRIPMILEAGE:C(PROVIDER)[T.Yellow Cab of DC]    -0.8051      0.010    -78.069      0.000      -0.825      -0.785
# ==============================================================================
# Omnibus:                    74025.143   Durbin-Watson:                   1.715
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         54319684.183
# Skew:                          -0.158   Prob(JB):                         0.00
# Kurtosis:                      84.453   Cond. No.                         73.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """

# %%
df["yellowcab"] = df.PROVIDER == "Yellow Cab of DC"
formula = "METERFARE ~ TRIPMILEAGE * yellowcab"
model = smf.ols(formula, df).fit(cov_type="HC1")
model.summary()
plt.rc('figure', figsize=(10, 6))
plt.text(0.01, 0.05, str(model.summary()), {'fontsize': 10}, fontproperties = 'monospace') # approach improved by OP -> monospace!
plt.axis('off')
plt.tight_layout()
plt.savefig('image/ols_meterfare_tripmileage_yellowcab')

# %%
formula = "TRIPMILEAGE ~ TRIPTIME"
model = smf.ols(formula, df).fit(cov_type="HC1")
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            TRIPMILEAGE   R-squared:                       0.441
# Model:                            OLS   Adj. R-squared:                  0.441
# Method:                 Least Squares   F-statistic:                 1.214e+04
# Date:                Tue, 30 Jul 2019   Prob (F-statistic):               0.00
# Time:                        17:56:35   Log-Likelihood:            -5.0645e+05
# No. Observations:              196493   AIC:                         1.013e+06
# Df Residuals:                  196491   BIC:                         1.013e+06
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9558      0.033    -29.202      0.000      -1.020      -0.892
# TRIPTIME       0.3027      0.003    110.199      0.000       0.297       0.308
# ==============================================================================
# Omnibus:                   177690.710   Durbin-Watson:                   1.756
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         19744343.251
# Skew:                           3.942   Prob(JB):                         0.00
# Kurtosis:                      51.471   Cond. No.                         29.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """

# %%
formula = "TIP ~ METERFARE"
model = smf.ols(formula, df.loc[df.tipping==1]).fit(cov_type="HC1")
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    TIP   R-squared:                       0.338
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     6891.
# Date:                Tue, 30 Jul 2019   Prob (F-statistic):               0.00
# Time:                        17:56:35   Log-Likelihood:            -1.8936e+05
# No. Observations:               89207   AIC:                         3.787e+05
# Df Residuals:                   89205   BIC:                         3.787e+05
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9832      0.023     43.449      0.000       0.939       1.028
# METERFARE      0.1623      0.002     83.011      0.000       0.158       0.166
# ==============================================================================
# Omnibus:                   290084.150   Durbin-Watson:                   1.857
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     152817983215.190
# Skew:                          54.444   Prob(JB):                         0.00
# Kurtosis:                    6414.073   Cond. No.                         25.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """

# %%
df.loc[df.PROVIDER=="Yellow Cab of DC", "TRIPMILEAGE"] = df.loc[df.PROVIDER=="Yellow Cab of DC", "TRIPMILEAGE"] / 1.6

# %%
plt.figure(figsize=(4.8, 3.6))
plt.scatter(df.TRIPMILEAGE, 
            df.METERFARE, 
            s=5, 
            alpha=0.6)
plt.xlabel("Mileage")
plt.ylabel("Meterfare")
plt.title("Mileage and Meterfare")
plt.tight_layout()
plt.savefig("image/meterfare_all_corrected")
plt.show()

# %%
formula = "METERFARE ~ TRIPMILEAGE"
model = smf.ols(formula, df).fit(cov_type="HC1")
model.summary()

plt.rc('figure', figsize=(8, 5))
plt.text(0.01, 0.05, str(model.summary()), {'fontsize': 10}, fontproperties = 'monospace')
plt.axis('off')
plt.tight_layout()
plt.savefig('image/ols_meterfare_tripmileage_corrected')

# %%
df["yellowcab"] = df.PROVIDER == "Yellow Cab of DC"
formula = "METERFARE ~ TRIPMILEAGE * yellowcab"
model = smf.ols(formula, df).fit(cov_type="HC1")
model.summary()
plt.rc('figure', figsize=(10, 6))
plt.text(0.01, 0.05, str(model.summary()), {'fontsize': 10}, fontproperties = 'monospace')
plt.axis('off')
plt.tight_layout()
plt.savefig('image/ols_meterfare_tripmileage_yellowcab_corrected')

# %%
plt.scatter(df.loc[df.tipping==1].METERFARE, df.loc[df.tipping==1].TIP)
plt.ylim(0,50)
# Out:
# (0, 50)

# %%
formula = "TIP ~ METERFARE + C(PROVIDER) + AIRPORT + C(PAYMENTTYPE) + C(pickup_date) + C(pickup_hour)"
model = smf.ols(formula, df.loc[df.tipping==1]).fit(cov_type="HC1")
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    TIP   R-squared:                       0.349
# Model:                            OLS   Adj. R-squared:                  0.348
# Method:                 Least Squares   F-statistic:                     455.6
# Date:                Tue, 30 Jul 2019   Prob (F-statistic):               0.00
# Time:                        17:56:40   Log-Likelihood:            -1.8862e+05
# No. Observations:               89207   AIC:                         3.773e+05
# Df Residuals:                   89166   BIC:                         3.777e+05
# Df Model:                          40
# Covariance Type:                  HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                        1.3845      0.078     17.718      0.000       1.231       1.538
# C(PROVIDER)[T.DCVIP Cab]                         0.3136      0.042      7.481      0.000       0.231       0.396
# C(PROVIDER)[T.Hitch]                            -0.6431      0.206     -3.117      0.002      -1.047      -0.239
# C(PROVIDER)[T.My Taxi Control]                  -0.4768      0.061     -7.831      0.000      -0.596      -0.358
# C(PROVIDER)[T.Transco, Inc.]                    -0.0356      0.014     -2.576      0.010      -0.063      -0.008
# C(PROVIDER)[T.United Ventures]                  -0.0288      0.014     -2.089      0.037      -0.056      -0.002
# C(PROVIDER)[T.Verifone]                         -0.0385      0.013     -3.018      0.003      -0.064      -0.014
# C(PROVIDER)[T.Yellow Cab of DC]                 -0.2829      0.057     -4.995      0.000      -0.394      -0.172
# AIRPORT[T.True]                                  0.4260      0.030     14.022      0.000       0.366       0.486
# C(PAYMENTTYPE)[T.CreditCard]                    -0.2918      0.053     -5.476      0.000      -0.396      -0.187
# C(PAYMENTTYPE)[T.Voucher]                       -0.7110      0.087     -8.143      0.000      -0.882      -0.540
# C(pickup_date)[T.datetime.date(2017, 7, 24)]    -0.0414      0.029     -1.449      0.147      -0.097       0.015
# C(pickup_date)[T.datetime.date(2017, 7, 25)]    -0.0617      0.026     -2.376      0.017      -0.113      -0.011
# C(pickup_date)[T.datetime.date(2017, 7, 26)]    -0.0234      0.032     -0.727      0.467      -0.087       0.040
# C(pickup_date)[T.datetime.date(2017, 7, 27)]    -0.0533      0.027     -1.976      0.048      -0.106      -0.000
# C(pickup_date)[T.datetime.date(2017, 7, 28)]    -0.0818      0.026     -3.092      0.002      -0.134      -0.030
# C(pickup_date)[T.datetime.date(2017, 7, 29)]     0.0143      0.040      0.357      0.721      -0.064       0.093
# C(pickup_hour)[T.1]                              0.0257      0.146      0.176      0.860      -0.261       0.312
# C(pickup_hour)[T.2]                              0.0490      0.146      0.335      0.738      -0.238       0.336
# C(pickup_hour)[T.3]                             -0.1971      0.091     -2.162      0.031      -0.376      -0.018
# C(pickup_hour)[T.4]                             -0.3205      0.107     -2.986      0.003      -0.531      -0.110
# C(pickup_hour)[T.5]                             -0.2628      0.110     -2.389      0.017      -0.478      -0.047
# C(pickup_hour)[T.6]                             -0.2195      0.075     -2.928      0.003      -0.366      -0.073
# C(pickup_hour)[T.7]                             -0.1650      0.061     -2.692      0.007      -0.285      -0.045
# C(pickup_hour)[T.8]                             -0.1652      0.055     -3.010      0.003      -0.273      -0.058
# C(pickup_hour)[T.9]                             -0.1917      0.068     -2.811      0.005      -0.325      -0.058
# C(pickup_hour)[T.10]                            -0.1991      0.053     -3.756      0.000      -0.303      -0.095
# C(pickup_hour)[T.11]                            -0.1871      0.053     -3.555      0.000      -0.290      -0.084
# C(pickup_hour)[T.12]                            -0.2036      0.053     -3.842      0.000      -0.307      -0.100
# C(pickup_hour)[T.13]                            -0.1889      0.054     -3.510      0.000      -0.294      -0.083
# C(pickup_hour)[T.14]                            -0.1673      0.056     -2.984      0.003      -0.277      -0.057
# C(pickup_hour)[T.15]                            -0.1614      0.054     -2.987      0.003      -0.267      -0.056
# C(pickup_hour)[T.16]                            -0.1343      0.053     -2.521      0.012      -0.239      -0.030
# C(pickup_hour)[T.17]                            -0.0897      0.070     -1.277      0.202      -0.227       0.048
# C(pickup_hour)[T.18]                            -0.1558      0.055     -2.842      0.004      -0.263      -0.048
# C(pickup_hour)[T.19]                            -0.1099      0.053     -2.063      0.039      -0.214      -0.005
# C(pickup_hour)[T.20]                            -0.0875      0.054     -1.629      0.103      -0.193       0.018
# C(pickup_hour)[T.21]                            -0.0485      0.054     -0.895      0.371      -0.155       0.058
# C(pickup_hour)[T.22]                            -0.0603      0.056     -1.086      0.277      -0.169       0.049
# C(pickup_hour)[T.23]                            -0.0488      0.058     -0.841      0.400      -0.162       0.065
# METERFARE                                        0.1570      0.002     66.042      0.000       0.152       0.162
# ==============================================================================
# Omnibus:                   291988.868   Durbin-Watson:                   1.874
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     161806931995.161
# Skew:                          55.486   Prob(JB):                         0.00
# Kurtosis:                    6599.951   Cond. No.                     1.31e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The condition number is large, 1.31e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df.loc[df.TIP<20].TIP.hist(bins=21)

# %%
formula = "tipping ~ TRIPMILEAGE + C(PROVIDER) + AIRPORT + C(PAYMENTTYPE) + C(pickup_date) + C(pickup_hour) + C(TRIPTYPE)"
logit1 = smf.logit(formula, df).fit(cov_type="HC1")
logit1.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.223078
#          Iterations 12
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                tipping   No. Observations:               196493
# Model:                          Logit   Df Residuals:                   196450
# Method:                           MLE   Df Model:                           42
# Date:                Tue, 30 Jul 2019   Pseudo R-squ.:                  0.6762
# Time:                        21:49:43   Log-Likelihood:                -43833.
# converged:                       True   LL-Null:                   -1.3537e+05
#                                         LLR p-value:                     0.000
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -4.0460      0.171    -23.665      0.000      -4.381      -3.711
# C(PROVIDER)[T.DCVIP Cab]                         4.4731      0.050     88.653      0.000       4.374       4.572
# C(PROVIDER)[T.Hitch]                            -9.6982      0.291    -33.274      0.000     -10.269      -9.127
# C(PROVIDER)[T.My Taxi Control]                   3.9407      0.061     64.233      0.000       3.820       4.061
# C(PROVIDER)[T.Transco, Inc.]                    -0.7521      0.035    -21.664      0.000      -0.820      -0.684
# C(PROVIDER)[T.United Ventures]                   0.1641      0.034      4.773      0.000       0.097       0.231
# C(PROVIDER)[T.Verifone]                         -0.6190      0.034    -18.190      0.000      -0.686      -0.552
# C(PROVIDER)[T.Yellow Cab of DC]                  3.9429      0.046     86.466      0.000       3.853       4.032
# AIRPORT[T.True]                                  0.5229      0.032     16.518      0.000       0.461       0.585
# C(PAYMENTTYPE)[T.CreditCard]                     7.0725      0.049    143.528      0.000       6.976       7.169
# C(PAYMENTTYPE)[T.Voucher]                        6.4062      0.245     26.170      0.000       5.926       6.886
# C(pickup_date)[T.datetime.date(2017, 7, 24)]     0.3725      0.036     10.427      0.000       0.302       0.442
# C(pickup_date)[T.datetime.date(2017, 7, 25)]     0.5009      0.035     14.313      0.000       0.432       0.570
# C(pickup_date)[T.datetime.date(2017, 7, 26)]     0.5607      0.035     16.213      0.000       0.493       0.629
# C(pickup_date)[T.datetime.date(2017, 7, 27)]     0.5461      0.034     15.855      0.000       0.479       0.614
# C(pickup_date)[T.datetime.date(2017, 7, 28)]     0.3030      0.035      8.694      0.000       0.235       0.371
# C(pickup_date)[T.datetime.date(2017, 7, 29)]    -0.0465      0.038     -1.217      0.223      -0.121       0.028
# C(pickup_hour)[T.1]                             -0.1630      0.095     -1.717      0.086      -0.349       0.023
# C(pickup_hour)[T.2]                             -0.1539      0.097     -1.583      0.113      -0.344       0.037
# C(pickup_hour)[T.3]                             -0.3024      0.117     -2.588      0.010      -0.531      -0.073
# C(pickup_hour)[T.4]                             -0.6575      0.127     -5.169      0.000      -0.907      -0.408
# C(pickup_hour)[T.5]                             -0.5164      0.118     -4.387      0.000      -0.747      -0.286
# C(pickup_hour)[T.6]                             -0.4953      0.095     -5.216      0.000      -0.681      -0.309
# C(pickup_hour)[T.7]                             -0.3503      0.077     -4.529      0.000      -0.502      -0.199
# C(pickup_hour)[T.8]                             -0.1789      0.071     -2.515      0.012      -0.318      -0.039
# C(pickup_hour)[T.9]                             -0.0240      0.069     -0.348      0.728      -0.159       0.111
# C(pickup_hour)[T.10]                            -0.1105      0.069     -1.607      0.108      -0.245       0.024
# C(pickup_hour)[T.11]                             0.1434      0.067      2.131      0.033       0.011       0.275
# C(pickup_hour)[T.12]                             0.0279      0.067      0.417      0.677      -0.103       0.159
# C(pickup_hour)[T.13]                             0.1443      0.067      2.151      0.031       0.013       0.276
# C(pickup_hour)[T.14]                             0.0326      0.067      0.484      0.628      -0.100       0.165
# C(pickup_hour)[T.15]                            -0.0164      0.067     -0.243      0.808      -0.148       0.115
# C(pickup_hour)[T.16]                             0.0226      0.067      0.336      0.737      -0.109       0.155
# C(pickup_hour)[T.17]                             0.0962      0.068      1.420      0.155      -0.037       0.229
# C(pickup_hour)[T.18]                             0.1357      0.068      1.999      0.046       0.003       0.269
# C(pickup_hour)[T.19]                             0.1608      0.070      2.297      0.022       0.024       0.298
# C(pickup_hour)[T.20]                             0.1045      0.071      1.464      0.143      -0.035       0.244
# C(pickup_hour)[T.21]                             0.0670      0.072      0.933      0.351      -0.074       0.208
# C(pickup_hour)[T.22]                             0.0236      0.072      0.327      0.743      -0.118       0.165
# C(pickup_hour)[T.23]                            -0.1238      0.077     -1.602      0.109      -0.275       0.028
# C(TRIPTYPE)[T.PSP]                              -0.5590      0.152     -3.685      0.000      -0.856      -0.262
# C(TRIPTYPE)[T.TRANSPORT-DC]                     -9.4916      0.859    -11.050      0.000     -11.175      -7.808
# TRIPMILEAGE                                     -0.0281      0.002    -11.896      0.000      -0.033      -0.023
# ================================================================================================================
# """

# %%
formula = "tipping ~ TRIPMILEAGE + C(PROVIDER) + AIRPORT + C(PAYMENTTYPE) + C(pickup_date) + C(pickup_hour) + C(TRIPTYPE) + C(dropoff_quadrant)"
logit2 = smf.logit(formula, df).fit(cov_type="HC1")
logit2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.213627
#          Iterations 12
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                tipping   No. Observations:               155050
# Model:                          Logit   Df Residuals:                   155004
# Method:                           MLE   Df Model:                           45
# Date:                Tue, 30 Jul 2019   Pseudo R-squ.:                  0.6895
# Time:                        21:49:57   Log-Likelihood:                -33123.
# converged:                       True   LL-Null:                   -1.0668e+05
#                                         LLR p-value:                     0.000
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -4.1265      0.193    -21.397      0.000      -4.505      -3.749
# C(PROVIDER)[T.DCVIP Cab]                         4.6217      0.058     79.157      0.000       4.507       4.736
# C(PROVIDER)[T.Hitch]                            -9.9237      0.357    -27.831      0.000     -10.623      -9.225
# C(PROVIDER)[T.My Taxi Control]                   4.0180      0.070     57.783      0.000       3.882       4.154
# C(PROVIDER)[T.Transco, Inc.]                    -0.7983      0.040    -19.877      0.000      -0.877      -0.720
# C(PROVIDER)[T.United Ventures]                   0.1511      0.039      3.829      0.000       0.074       0.228
# C(PROVIDER)[T.Verifone]                         -0.6617      0.040    -16.611      0.000      -0.740      -0.584
# C(PROVIDER)[T.Yellow Cab of DC]                  4.0525      0.053     76.190      0.000       3.948       4.157
# AIRPORT[T.True]                                  0.4787      0.052      9.211      0.000       0.377       0.581
# C(PAYMENTTYPE)[T.CreditCard]                     7.2280      0.057    125.842      0.000       7.115       7.341
# C(PAYMENTTYPE)[T.Voucher]                        6.5928      0.280     23.572      0.000       6.045       7.141
# C(pickup_date)[T.datetime.date(2017, 7, 24)]     0.3672      0.042      8.746      0.000       0.285       0.449
# C(pickup_date)[T.datetime.date(2017, 7, 25)]     0.4828      0.041     11.688      0.000       0.402       0.564
# C(pickup_date)[T.datetime.date(2017, 7, 26)]     0.5324      0.041     13.040      0.000       0.452       0.612
# C(pickup_date)[T.datetime.date(2017, 7, 27)]     0.5262      0.041     12.917      0.000       0.446       0.606
# C(pickup_date)[T.datetime.date(2017, 7, 28)]     0.2796      0.041      6.800      0.000       0.199       0.360
# C(pickup_date)[T.datetime.date(2017, 7, 29)]    -0.0853      0.045     -1.899      0.058      -0.173       0.003
# C(pickup_hour)[T.1]                             -0.1716      0.109     -1.572      0.116      -0.385       0.042
# C(pickup_hour)[T.2]                             -0.1188      0.114     -1.038      0.299      -0.343       0.105
# C(pickup_hour)[T.3]                             -0.2363      0.154     -1.538      0.124      -0.537       0.065
# C(pickup_hour)[T.4]                             -0.9437      0.211     -4.476      0.000      -1.357      -0.530
# C(pickup_hour)[T.5]                             -1.1248      0.205     -5.475      0.000      -1.527      -0.722
# C(pickup_hour)[T.6]                             -0.7629      0.127     -6.023      0.000      -1.011      -0.515
# C(pickup_hour)[T.7]                             -0.4047      0.090     -4.482      0.000      -0.582      -0.228
# C(pickup_hour)[T.8]                             -0.1315      0.082     -1.603      0.109      -0.292       0.029
# C(pickup_hour)[T.9]                             -0.0108      0.079     -0.137      0.891      -0.165       0.144
# C(pickup_hour)[T.10]                            -0.1270      0.079     -1.610      0.107      -0.282       0.028
# C(pickup_hour)[T.11]                             0.1743      0.077      2.259      0.024       0.023       0.326
# C(pickup_hour)[T.12]                             0.0291      0.077      0.378      0.705      -0.122       0.180
# C(pickup_hour)[T.13]                             0.1602      0.077      2.083      0.037       0.009       0.311
# C(pickup_hour)[T.14]                             0.0508      0.077      0.658      0.511      -0.100       0.202
# C(pickup_hour)[T.15]                            -0.0359      0.077     -0.464      0.642      -0.187       0.116
# C(pickup_hour)[T.16]                            -0.0097      0.077     -0.126      0.899      -0.161       0.141
# C(pickup_hour)[T.17]                             0.1042      0.077      1.348      0.178      -0.047       0.256
# C(pickup_hour)[T.18]                             0.1208      0.077      1.560      0.119      -0.031       0.273
# C(pickup_hour)[T.19]                             0.1413      0.080      1.772      0.076      -0.015       0.298
# C(pickup_hour)[T.20]                             0.0927      0.082      1.129      0.259      -0.068       0.254
# C(pickup_hour)[T.21]                             0.0869      0.082      1.056      0.291      -0.074       0.248
# C(pickup_hour)[T.22]                             0.0429      0.083      0.516      0.606      -0.120       0.206
# C(pickup_hour)[T.23]                            -0.0887      0.089     -0.994      0.320      -0.264       0.086
# C(TRIPTYPE)[T.PSP]                              -0.6346      0.167     -3.809      0.000      -0.961      -0.308
# C(TRIPTYPE)[T.TRANSPORT-DC]                     -9.5172      0.897    -10.605      0.000     -11.276      -7.758
# C(dropoff_quadrant)[T.NW]                        0.2216      0.032      6.901      0.000       0.159       0.285
# C(dropoff_quadrant)[T.SE]                        0.1395      0.050      2.804      0.005       0.042       0.237
# C(dropoff_quadrant)[T.SW]                        0.1117      0.048      2.329      0.020       0.018       0.206
# TRIPMILEAGE                                     -0.0801      0.007    -11.475      0.000      -0.094      -0.066
# ================================================================================================================
# """

# %%
formula = "tipping ~ TRIPMILEAGE + C(PROVIDER) + AIRPORT + C(PAYMENTTYPE) + C(pickup_date) + C(pickup_hour) + C(TRIPTYPE) + C(dropoff_quadrant) + distance_capitol"
logit3 = smf.logit(formula, df).fit(cov_type="HC1")
logit3.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.212886
#          Iterations 12
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                tipping   No. Observations:               155050
# Model:                          Logit   Df Residuals:                   155003
# Method:                           MLE   Df Model:                           46
# Date:                Tue, 30 Jul 2019   Pseudo R-squ.:                  0.6906
# Time:                        21:50:07   Log-Likelihood:                -33008.
# converged:                       True   LL-Null:                   -1.0668e+05
#                                         LLR p-value:                     0.000
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -3.9760      0.192    -20.711      0.000      -4.352      -3.600
# C(PROVIDER)[T.DCVIP Cab]                         4.6329      0.059     79.163      0.000       4.518       4.748
# C(PROVIDER)[T.Hitch]                            -9.9446      0.357    -27.885      0.000     -10.644      -9.246
# C(PROVIDER)[T.My Taxi Control]                   4.0164      0.070     57.682      0.000       3.880       4.153
# C(PROVIDER)[T.Transco, Inc.]                    -0.7933      0.040    -19.741      0.000      -0.872      -0.715
# C(PROVIDER)[T.United Ventures]                   0.1534      0.039      3.889      0.000       0.076       0.231
# C(PROVIDER)[T.Verifone]                         -0.6592      0.040    -16.528      0.000      -0.737      -0.581
# C(PROVIDER)[T.Yellow Cab of DC]                  4.0651      0.053     76.305      0.000       3.961       4.170
# AIRPORT[T.True]                                  0.3770      0.052      7.292      0.000       0.276       0.478
# C(PAYMENTTYPE)[T.CreditCard]                     7.2252      0.058    125.594      0.000       7.112       7.338
# C(PAYMENTTYPE)[T.Voucher]                        6.5935      0.279     23.648      0.000       6.047       7.140
# C(pickup_date)[T.datetime.date(2017, 7, 24)]     0.3556      0.042      8.450      0.000       0.273       0.438
# C(pickup_date)[T.datetime.date(2017, 7, 25)]     0.4660      0.041     11.250      0.000       0.385       0.547
# C(pickup_date)[T.datetime.date(2017, 7, 26)]     0.5095      0.041     12.451      0.000       0.429       0.590
# C(pickup_date)[T.datetime.date(2017, 7, 27)]     0.5058      0.041     12.389      0.000       0.426       0.586
# C(pickup_date)[T.datetime.date(2017, 7, 28)]     0.2718      0.041      6.599      0.000       0.191       0.353
# C(pickup_date)[T.datetime.date(2017, 7, 29)]    -0.0854      0.045     -1.898      0.058      -0.174       0.003
# C(pickup_hour)[T.1]                             -0.1747      0.109     -1.599      0.110      -0.389       0.039
# C(pickup_hour)[T.2]                             -0.1142      0.115     -0.993      0.321      -0.340       0.111
# C(pickup_hour)[T.3]                             -0.2271      0.155     -1.463      0.144      -0.531       0.077
# C(pickup_hour)[T.4]                             -0.9556      0.208     -4.590      0.000      -1.364      -0.548
# C(pickup_hour)[T.5]                             -1.1574      0.205     -5.658      0.000      -1.558      -0.756
# C(pickup_hour)[T.6]                             -0.8311      0.127     -6.567      0.000      -1.079      -0.583
# C(pickup_hour)[T.7]                             -0.4750      0.091     -5.244      0.000      -0.653      -0.298
# C(pickup_hour)[T.8]                             -0.1987      0.082     -2.410      0.016      -0.360      -0.037
# C(pickup_hour)[T.9]                             -0.0834      0.079     -1.050      0.294      -0.239       0.072
# C(pickup_hour)[T.10]                            -0.1947      0.079     -2.455      0.014      -0.350      -0.039
# C(pickup_hour)[T.11]                             0.0971      0.078      1.250      0.211      -0.055       0.249
# C(pickup_hour)[T.12]                            -0.0434      0.077     -0.561      0.574      -0.195       0.108
# C(pickup_hour)[T.13]                             0.0896      0.077      1.159      0.247      -0.062       0.241
# C(pickup_hour)[T.14]                            -0.0097      0.078     -0.125      0.900      -0.162       0.142
# C(pickup_hour)[T.15]                            -0.0978      0.078     -1.258      0.208      -0.250       0.055
# C(pickup_hour)[T.16]                            -0.0682      0.077     -0.880      0.379      -0.220       0.084
# C(pickup_hour)[T.17]                             0.0605      0.078      0.779      0.436      -0.092       0.213
# C(pickup_hour)[T.18]                             0.0845      0.078      1.087      0.277      -0.068       0.237
# C(pickup_hour)[T.19]                             0.1026      0.080      1.281      0.200      -0.054       0.260
# C(pickup_hour)[T.20]                             0.0696      0.083      0.844      0.399      -0.092       0.231
# C(pickup_hour)[T.21]                             0.0620      0.083      0.751      0.453      -0.100       0.224
# C(pickup_hour)[T.22]                             0.0196      0.083      0.235      0.814      -0.144       0.183
# C(pickup_hour)[T.23]                            -0.0914      0.090     -1.020      0.308      -0.267       0.084
# C(TRIPTYPE)[T.PSP]                              -0.6441      0.165     -3.892      0.000      -0.968      -0.320
# C(TRIPTYPE)[T.TRANSPORT-DC]                     -9.4020      0.897    -10.476      0.000     -11.161      -7.643
# C(dropoff_quadrant)[T.NW]                        0.4022      0.034     11.717      0.000       0.335       0.469
# C(dropoff_quadrant)[T.SE]                        0.1195      0.050      2.401      0.016       0.022       0.217
# C(dropoff_quadrant)[T.SW]                        0.1081      0.048      2.257      0.024       0.014       0.202
# TRIPMILEAGE                                     -0.0447      0.007     -6.552      0.000      -0.058      -0.031
# distance_capitol                                -8.9626      0.582    -15.413      0.000     -10.102      -7.823
# ================================================================================================================
# """

# %%
formula = "tipping ~ TRIPMILEAGE + C(PROVIDER) + AIRPORT + C(PAYMENTTYPE) + C(pickup_date) + C(pickup_hour) + C(TRIPTYPE) + C(dropoff_quadrant) * distance_capitol"
logit4 = smf.logit(formula, df).fit(cov_type="HC1")
logit4.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.211862
#          Iterations 12
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                tipping   No. Observations:               155050
# Model:                          Logit   Df Residuals:                   155000
# Method:                           MLE   Df Model:                           49
# Date:                Tue, 30 Jul 2019   Pseudo R-squ.:                  0.6921
# Time:                        21:50:20   Log-Likelihood:                -32849.
# converged:                       True   LL-Null:                   -1.0668e+05
#                                         LLR p-value:                     0.000
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -3.5684      0.195    -18.310      0.000      -3.950      -3.186
# C(PROVIDER)[T.DCVIP Cab]                         4.6370      0.059     79.226      0.000       4.522       4.752
# C(PROVIDER)[T.Hitch]                            -9.9485      0.357    -27.896      0.000     -10.648      -9.250
# C(PROVIDER)[T.My Taxi Control]                   4.0070      0.070     57.589      0.000       3.871       4.143
# C(PROVIDER)[T.Transco, Inc.]                    -0.7758      0.040    -19.249      0.000      -0.855      -0.697
# C(PROVIDER)[T.United Ventures]                   0.1502      0.039      3.810      0.000       0.073       0.227
# C(PROVIDER)[T.Verifone]                         -0.6613      0.040    -16.558      0.000      -0.740      -0.583
# C(PROVIDER)[T.Yellow Cab of DC]                  4.0831      0.053     76.648      0.000       3.979       4.187
# AIRPORT[T.True]                                  0.3627      0.052      7.035      0.000       0.262       0.464
# C(PAYMENTTYPE)[T.CreditCard]                     7.2202      0.058    125.458      0.000       7.107       7.333
# C(PAYMENTTYPE)[T.Voucher]                        6.6043      0.278     23.729      0.000       6.059       7.150
# C(pickup_date)[T.datetime.date(2017, 7, 24)]     0.3586      0.042      8.503      0.000       0.276       0.441
# C(pickup_date)[T.datetime.date(2017, 7, 25)]     0.4641      0.042     11.165      0.000       0.383       0.546
# C(pickup_date)[T.datetime.date(2017, 7, 26)]     0.5041      0.041     12.282      0.000       0.424       0.585
# C(pickup_date)[T.datetime.date(2017, 7, 27)]     0.5039      0.041     12.306      0.000       0.424       0.584
# C(pickup_date)[T.datetime.date(2017, 7, 28)]     0.2792      0.041      6.751      0.000       0.198       0.360
# C(pickup_date)[T.datetime.date(2017, 7, 29)]    -0.0868      0.045     -1.925      0.054      -0.175       0.002
# C(pickup_hour)[T.1]                             -0.1713      0.111     -1.547      0.122      -0.388       0.046
# C(pickup_hour)[T.2]                             -0.1178      0.116     -1.017      0.309      -0.345       0.109
# C(pickup_hour)[T.3]                             -0.2113      0.157     -1.344      0.179      -0.520       0.097
# C(pickup_hour)[T.4]                             -0.9666      0.212     -4.570      0.000      -1.381      -0.552
# C(pickup_hour)[T.5]                             -1.2191      0.206     -5.911      0.000      -1.623      -0.815
# C(pickup_hour)[T.6]                             -0.8836      0.126     -6.988      0.000      -1.131      -0.636
# C(pickup_hour)[T.7]                             -0.5125      0.091     -5.653      0.000      -0.690      -0.335
# C(pickup_hour)[T.8]                             -0.2371      0.083     -2.863      0.004      -0.399      -0.075
# C(pickup_hour)[T.9]                             -0.1190      0.080     -1.492      0.136      -0.275       0.037
# C(pickup_hour)[T.10]                            -0.2259      0.080     -2.836      0.005      -0.382      -0.070
# C(pickup_hour)[T.11]                             0.0687      0.078      0.882      0.378      -0.084       0.221
# C(pickup_hour)[T.12]                            -0.0644      0.078     -0.829      0.407      -0.217       0.088
# C(pickup_hour)[T.13]                             0.0637      0.078      0.821      0.411      -0.088       0.216
# C(pickup_hour)[T.14]                            -0.0371      0.078     -0.476      0.634      -0.190       0.116
# C(pickup_hour)[T.15]                            -0.1218      0.078     -1.558      0.119      -0.275       0.031
# C(pickup_hour)[T.16]                            -0.0848      0.078     -1.091      0.275      -0.237       0.068
# C(pickup_hour)[T.17]                             0.0386      0.078      0.495      0.621      -0.114       0.191
# C(pickup_hour)[T.18]                             0.0693      0.078      0.887      0.375      -0.084       0.222
# C(pickup_hour)[T.19]                             0.0895      0.080      1.113      0.266      -0.068       0.247
# C(pickup_hour)[T.20]                             0.0527      0.083      0.636      0.524      -0.110       0.215
# C(pickup_hour)[T.21]                             0.0627      0.083      0.756      0.450      -0.100       0.225
# C(pickup_hour)[T.22]                             0.0191      0.084      0.228      0.820      -0.145       0.183
# C(pickup_hour)[T.23]                            -0.0836      0.090     -0.925      0.355      -0.261       0.093
# C(TRIPTYPE)[T.PSP]                              -0.6597      0.166     -3.966      0.000      -0.986      -0.334
# C(TRIPTYPE)[T.TRANSPORT-DC]                     -9.2986      0.907    -10.246      0.000     -11.077      -7.520
# C(dropoff_quadrant)[T.NW]                       -0.1373      0.051     -2.680      0.007      -0.238      -0.037
# C(dropoff_quadrant)[T.SE]                        0.2266      0.077      2.924      0.003       0.075       0.378
# C(dropoff_quadrant)[T.SW]                       -0.1377      0.078     -1.756      0.079      -0.291       0.016
# TRIPMILEAGE                                     -0.0398      0.007     -5.860      0.000      -0.053      -0.026
# distance_capitol                               -29.8628      1.811    -16.490      0.000     -33.412     -26.313
# C(dropoff_quadrant)[T.NW]:distance_capitol      25.0324      1.888     13.255      0.000      21.331      28.734
# C(dropoff_quadrant)[T.SE]:distance_capitol      -8.4831      3.438     -2.468      0.014     -15.221      -1.745
# C(dropoff_quadrant)[T.SW]:distance_capitol      12.2684      3.798      3.230      0.001       4.824      19.712
# ================================================================================================================
# """

# %%
import statsmodels.iolib as iolib
info_dict={'Pseudo R-squ.' : lambda x: f"{x.prsquared:.4f}",
           'No. observations' : lambda x: f"{int(x.nobs):d}"}
summary_table = iolib.summary2.summary_col([logit1, 
                                            logit2, 
                                            logit3, 
                                            logit4],
                                           stars=True, 
                                           model_names=["Logit 1", 
                                                        "Logit 2", 
                                                        "Logit 3", 
                                                        "Logit 4"],
                                           regressor_order=["AIRPORT[T.True]",
                                                            "C(PAYMENTTYPE)[T.CreditCard]",
                                                            "C(PAYMENTTYPE)[T.Voucher]",
                                                            'TRIPMILEAGE',
                                                            'C(dropoff_quadrant)[T.NW]',
                                                            'C(dropoff_quadrant)[T.SE]',
                                                            'C(dropoff_quadrant)[T.SW]',
                                                            'distance_capitol',
                                                            'C(dropoff_quadrant)[T.NW]:distance_capitol',
                                                            'C(dropoff_quadrant)[T.SE]:distance_capitol',
                                                            'C(dropoff_quadrant)[T.SW]:distance_capitol'],
                                          info_dict=info_dict)

# %%
control = pd.DataFrame(index=["Control Quadrant", "Control Date/Hour", "Control Provider/Type"],
                       columns=["Logit 1", "Logit 2", "Logit 3", "Logit 4"],
                       data=[["N", "Y", "Y", "Y"], ["Y", "Y", "Y", "Y"], ["Y", "Y", "Y", "Y"]])

# %%
summary = pd.concat([summary_table.tables[0].iloc[0:22],
                     control,
                     summary_table.tables[0].iloc[-2:]])

# %%
summary
# Out:
#                                                Logit 1     Logit 2  \
# AIRPORT[T.True]                              0.5229***   0.4787***
#                                               (0.0317)    (0.0520)
# C(PAYMENTTYPE)[T.CreditCard]                 7.0725***   7.2280***
#                                               (0.0493)    (0.0574)
# C(PAYMENTTYPE)[T.Voucher]                    6.4062***   6.5928***
#                                               (0.2448)    (0.2797)
# TRIPMILEAGE                                 -0.0281***  -0.0801***
#                                               (0.0024)    (0.0070)
# C(dropoff_quadrant)[T.NW]                                0.2216***
#                                                           (0.0321)
# C(dropoff_quadrant)[T.SE]                                0.1395***
#                                                           (0.0497)
# C(dropoff_quadrant)[T.SW]                                 0.1117**
#                                                           (0.0479)
# distance_capitol
#
# C(dropoff_quadrant)[T.NW]:distance_capitol
#
# C(dropoff_quadrant)[T.SE]:distance_capitol
#
# C(dropoff_quadrant)[T.SW]:distance_capitol
#
# Control Quadrant                                     N           Y
# Control Date/Hour                                    Y           Y
# Control Provider/Type                                Y           Y
# Pseudo R-squ.                                   0.6762      0.6895
# No. observations                                196493      155050
#
#                                                Logit 3      Logit 4
# AIRPORT[T.True]                              0.3770***    0.3627***
#                                               (0.0517)     (0.0516)
# C(PAYMENTTYPE)[T.CreditCard]                 7.2252***    7.2202***
#                                               (0.0575)     (0.0576)
# C(PAYMENTTYPE)[T.Voucher]                    6.5935***    6.6043***
#                                               (0.2788)     (0.2783)
# TRIPMILEAGE                                 -0.0447***   -0.0398***
#                                               (0.0068)     (0.0068)
# C(dropoff_quadrant)[T.NW]                    0.4022***   -0.1373***
#                                               (0.0343)     (0.0512)
# C(dropoff_quadrant)[T.SE]                     0.1195**    0.2266***
#                                               (0.0498)     (0.0775)
# C(dropoff_quadrant)[T.SW]                     0.1081**     -0.1377*
#                                               (0.0479)     (0.0784)
# distance_capitol                            -8.9626***  -29.8628***
#                                               (0.5815)     (1.8109)
# C(dropoff_quadrant)[T.NW]:distance_capitol               25.0324***
#                                                            (1.8885)
# C(dropoff_quadrant)[T.SE]:distance_capitol                -8.4831**
#                                                            (3.4377)
# C(dropoff_quadrant)[T.SW]:distance_capitol               12.2684***
#                                                            (3.7981)
# Control Quadrant                                     Y            Y
# Control Date/Hour                                    Y            Y
# Control Provider/Type                                Y            Y
# Pseudo R-squ.                                   0.6906       0.6921
# No. observations                                155050       155050

# %%
summary.index=['Airport',
               '',
               'Credit Card',
               '',
               'Voucher',
               '',
               'Trip Mileage',
               '',
               'Drop-off Quadrant NW',
               '',
               'Drop-off Quadrant SE',
               '',
               'Drop-off Quadrant SW]',
               '',
               'Distance from Capitol',
               '',
               'Drop-off Quadrant NW',
               '* Distance from Capitol',
               'Drop-off Quadrant SE',
               '* Distance from Capitol',
               'Drop-off Quadrant SW',
               '* Distance from Capitol',
               "Control Quadrant",
               "Control Date/Hour",
               "Control Provider/Type",
               'Pseudo R-squared',
               'No. observations']
summary
# Out:
#                             Logit 1     Logit 2     Logit 3      Logit 4
# Airport                   0.5229***   0.4787***   0.3770***    0.3627***
#                            (0.0317)    (0.0520)    (0.0517)     (0.0516)
# Credit Card               7.0725***   7.2280***   7.2252***    7.2202***
#                            (0.0493)    (0.0574)    (0.0575)     (0.0576)
# Voucher                   6.4062***   6.5928***   6.5935***    6.6043***
#                            (0.2448)    (0.2797)    (0.2788)     (0.2783)
# Trip Mileage             -0.0281***  -0.0801***  -0.0447***   -0.0398***
#                            (0.0024)    (0.0070)    (0.0068)     (0.0068)
# Drop-off Quadrant NW                  0.2216***   0.4022***   -0.1373***
#                                        (0.0321)    (0.0343)     (0.0512)
# Drop-off Quadrant SE                  0.1395***    0.1195**    0.2266***
#                                        (0.0497)    (0.0498)     (0.0775)
# Drop-off Quadrant SW]                  0.1117**    0.1081**     -0.1377*
#                                        (0.0479)    (0.0479)     (0.0784)
# Distance from Capitol                            -8.9626***  -29.8628***
#                                                    (0.5815)     (1.8109)
# Drop-off Quadrant NW                                          25.0324***
# * Distance from Capitol                                         (1.8885)
# Drop-off Quadrant SE                                           -8.4831**
# * Distance from Capitol                                         (3.4377)
# Drop-off Quadrant SW                                          12.2684***
# * Distance from Capitol                                         (3.7981)
# Control Quadrant                  N           Y           Y            Y
# Control Date/Hour                 Y           Y           Y            Y
# Control Provider/Type             Y           Y           Y            Y
# Pseudo R-squared             0.6762      0.6895      0.6906       0.6921
# No. observations             196493      155050      155050       155050

# %%
summary1 = pd.concat([summary.loc[:, ["Logit 1", "Logit 2"]].iloc[:14],
                      summary.loc[:, ["Logit 1", "Logit 2"]].iloc[-4:]])
summary1
# Out:
#                           Logit 1     Logit 2
# Airport                 0.5229***   0.4787***
#                          (0.0317)    (0.0520)
# Credit Card             7.0725***   7.2280***
#                          (0.0493)    (0.0574)
# Voucher                 6.4062***   6.5928***
#                          (0.2448)    (0.2797)
# Trip Mileage           -0.0281***  -0.0801***
#                          (0.0024)    (0.0070)
# Drop-off Quadrant NW                0.2216***
#                                      (0.0321)
# Drop-off Quadrant SE                0.1395***
#                                      (0.0497)
# Drop-off Quadrant SW]                0.1117**
#                                      (0.0479)
# Control Date/Hour               Y           Y
# Control Provider/Type           Y           Y
# Pseudo R-squared           0.6762      0.6895
# No. observations           196493      155050

# %%
summary.loc[:, ["Logit 1", "Logit 2"]].iloc[:14]
# Out:
#                           Logit 1     Logit 2
# Airport                 0.5006***   0.4415***
#                          (0.0315)    (0.0511)
# Credit Card             7.0683***   7.2235***
#                          (0.0492)    (0.0574)
# Voucher                 6.3998***   6.5849***
#                          (0.2452)    (0.2800)
# Trip Mileage           -0.0208***  -0.0653***
#                          (0.0021)    (0.0060)
# Drop-off Quadrant NW                0.2220***
#                                      (0.0322)
# Drop-off Quadrant SE                0.1422***
#                                      (0.0499)
# Drop-off Quadrant SW]                0.1126**
#                                      (0.0480)

# %%
summary.loc[:, ["Logit 1", "Logit 2"]].iloc[-4:]
# Out:
#                       Logit 1 Logit 2
# Control Date/Hour           Y       Y
# Control Provider/Type       Y       Y
# Pseudo R-squared       0.6761  0.6895
# No. observations       196493  155050

# %%
summary2 = pd.concat([summary.loc[:, ["Logit 3", "Logit 4"]].iloc[:8],
                      summary.loc[:, ["Logit 3", "Logit 4"]].iloc[-13:]])
summary2
# Out:
#                             Logit 3      Logit 4
# Airport                   0.3620***    0.3471***
#                            (0.0506)     (0.0505)
# Credit Card               7.2229***    7.2182***
#                            (0.0575)     (0.0575)
# Voucher                   6.5895***    6.6009***
#                            (0.2789)     (0.2786)
# Trip Mileage             -0.0381***   -0.0333***
#                            (0.0058)     (0.0057)
# Distance from Capitol    -8.9893***  -29.9535***
#                            (0.5791)     (1.8156)
# Drop-off Quadrant NW                  25.0571***
# * Distance from Capitol                 (1.8940)
# Drop-off Quadrant SE                   -8.2814**
# * Distance from Capitol                 (3.4600)
# Drop-off Quadrant SW                  12.3487***
# * Distance from Capitol                 (3.8098)
# Control Quadrant                  Y            Y
# Control Date/Hour                 Y            Y
# Control Provider/Type             Y            Y
# Pseudo R-squared             0.6906       0.6921
# No. observations             155050       155050

# %%
summary.loc[:, ["Logit 3", "Logit 4"]].iloc[:8]
# Out:
#                  Logit 3     Logit 4
# Airport        0.3620***   0.3471***
#                 (0.0506)    (0.0505)
# Credit Card    7.2229***   7.2182***
#                 (0.0575)    (0.0575)
# Voucher        6.5895***   6.6009***
#                 (0.2789)    (0.2786)
# Trip Mileage  -0.0381***  -0.0333***
#                 (0.0058)    (0.0057)

# %%
summary.loc[:, ["Logit 3", "Logit 4"]].iloc[-13:]
# Out:
#                             Logit 3      Logit 4
# Distance from Capitol    -8.9893***  -29.9535***
#                            (0.5791)     (1.8156)
# Drop-off Quadrant NW                  25.0571***
# * Distance from Capitol                 (1.8940)
# Drop-off Quadrant SE                   -8.2814**
# * Distance from Capitol                 (3.4600)
# Drop-off Quadrant SW                  12.3487***
# * Distance from Capitol                 (3.8098)
# Control Quadrant                  Y            Y
# Control Date/Hour                 Y            Y
# Control Provider/Type             Y            Y
# Pseudo R-squared             0.6906       0.6921
# No. observations             155050       155050

# %%
hypothesis = "-distance_capitol = C(dropoff_quadrant)[T.NW]:distance_capitol"

# %%
model.f_test(hypothesis)
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-45-2f77507d4b4b> in <module>
# ----> 1 model.f_test(hypothesis)
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in f_test(self, r_matrix, cov_p, scale, invcov)
#    1434         """
#    1435         res = self.wald_test(r_matrix, cov_p=cov_p, scale=scale,
# -> 1436                              invcov=invcov, use_f=True)
#    1437         return res
#    1438
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in wald_test(self, r_matrix, cov_p, scale, invcov, use_f)
#    1496         from patsy import DesignInfo
#    1497         names = self.model.data.param_names
# -> 1498         LC = DesignInfo(names).linear_constraint(r_matrix)
#    1499         r_matrix, q_matrix = LC.coefs, LC.constants
#    1500
#
# ~/anaconda3/lib/python3.7/site-packages/patsy/design_info.py in linear_constraint(self, constraint_likes)
#     534           di.linear_constraint("x1 = x2 = 3")
#     535         """
# --> 536         return linear_constraint(constraint_likes, self.column_names)
#     537
#     538     def describe(self):
#
# ~/anaconda3/lib/python3.7/site-packages/patsy/constraint.py in linear_constraint(constraint_like, variable_names)
#     401             if not isinstance(code, str):
#     402                 raise ValueError("expected a string, not %r" % (code,))
# --> 403             tree = parse_constraint(code, variable_names)
#     404             evaluator = _EvalConstraint(variable_names)
#     405             constraints.append(evaluator.eval(tree, constraint=True))
#
# ~/anaconda3/lib/python3.7/site-packages/patsy/constraint.py in parse_constraint(string, variable_names)
#     235
#     236 def parse_constraint(string, variable_names):
# --> 237     return infix_parse(_tokenize_constraint(string, variable_names),
#     238                        _ops, _atomic)
#     239
#
# ~/anaconda3/lib/python3.7/site-packages/patsy/constraint.py in _tokenize_constraint(string, variable_names)
#     194         offset = len(string) - len(leftover)
#     195         raise PatsyError("unrecognized token in constraint",
# --> 196                             Origin(string, offset, offset + 1))
#     197
#     198     return tokens
#
# PatsyError: unrecognized token in constraint
#     -distance_capitol = C(dropoff_quadrant)[T.NW]:distance_capitol
#      ^

# %%
plt.figure(figsize=(4.8, 3.6))
df.loc[df.tip_ratio<1].tip_ratio.hist(bins=100, density=True)
plt.title("Tip-Meterfare Ratio")
plt.xlabel("Tip-Meterfare Ratio")
plt.ylabel("% Observation")
plt.tight_layout()
plt.savefig("image/tip_meterfare_hist")
plt.show()

# %%
df.tipping.mean()
# Out:
# 0.45399581664486777

# %%
df.loc[(df.tip_ratio<1)&(df.tip_ratio>0)].tip_ratio.describe()
# Out:
# count    88238.000000
# mean         0.263693
# std          0.125080
# min          0.000137
# 25%          0.203069
# 50%          0.232497
# 75%          0.300000
# max          0.996923
# Name: tip_ratio, dtype: float64

# %%
plt.figure(figsize=(4.8, 4.8))
df.groupby("pickup_datetime").tipping.mean().plot()
plt.title("Share of Trips w/Tip")
plt.ylabel("Percentage Points")
plt.xlabel("Pickup Date/Hour")

plt.tight_layout()
plt.savefig("image/tipping_overtime")
plt.show()
# Out:
# /Users/kmiyaki/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)

# %%
ts_tipping = df.groupby("pickup_datetime").tipping.mean()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_tipping, freq=24)
fig = plt.figure()
fig = decomposition.plot()
fig.set_size_inches(10, 10)
plt.xlabel("Pickup Date/Hour")
plt.tight_layout()
plt.savefig("image/time_series_decomposition")
plt.show()
# Out:
# /Users/kmiyaki/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
# /Users/kmiyaki/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
# /Users/kmiyaki/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
# /Users/kmiyaki/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)

# %%
from statsmodels.tsa.stattools import adfuller
pd.Series(adfuller(ts_tipping, autolag='AIC')[0:4], 
          index=['Test Statistic',
                 'p-value',
                 '#Lags Used',
                 'Number of Observations Used'])
# Out:
# Test Statistic                  -4.924534
# p-value                          0.000031
# #Lags Used                       4.000000
# Number of Observations Used    163.000000
# dtype: float64

# %%
fig,ax = plt.subplots(2,1,figsize=(20,10))
fig = sm.graphics.tsa.plot_acf(ts_tipping, lags=24, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(ts_tipping, lags=24, ax=ax[1])
plt.show()

# %%
# resDiff = sm.tsa.arma_order_select_ic(ts_tipping, max_ar=6, max_ma=3, ic='aic', trend='c')
# print('ARMA(p,q) =',resDiff['aic_min_order'],'is the best.')

# %%
sarima = sm.tsa.statespace.SARIMAX(ts_tipping,
                                  order=(4, 1, 2),
                                  freq='H',
                                  seasonal_order=(1, 1, 1, 24),
                                  enforce_stationarity=False,
                                  enforce_invertibility=False).fit()
sarima.summary()
# Out:
# /Users/kmiyaki/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                            tipping   No. Observations:                  168
# Model:             SARIMAX(4, 1, 2)x(1, 1, 1, 24)   Log Likelihood                 169.706
# Date:                            Tue, 30 Jul 2019   AIC                           -321.413
# Time:                                    19:38:43   BIC                           -296.708
# Sample:                                07-23-2017   HQIC                          -311.385
#                                      - 07-29-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -2.1792      0.199    -10.933      0.000      -2.570      -1.789
# ar.L2         -2.4218      0.338     -7.174      0.000      -3.083      -1.760
# ar.L3         -1.9914      0.257     -7.747      0.000      -2.495      -1.488
# ar.L4         -0.7763      0.122     -6.351      0.000      -1.016      -0.537
# ma.L1          2.8752      0.811      3.545      0.000       1.285       4.465
# ma.L2          1.8994      0.832      2.282      0.023       0.268       3.531
# ar.S.L24       0.0008      0.002      0.358      0.720      -0.003       0.005
# ma.S.L24      -0.3917      0.112     -3.499      0.000      -0.611      -0.172
# sigma2         0.0008      0.001      1.173      0.241      -0.001       0.002
# ===================================================================================
# Ljung-Box (Q):                       92.00   Jarque-Bera (JB):                23.76
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.90   Skew:                            -0.50
# Prob(H) (two-sided):                  0.05   Kurtosis:                         4.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
plt.rc('figure', figsize=(9, 6))
plt.text(0.01, 0.05, str(sarima.summary()), {'fontsize': 10}, fontproperties = 'monospace') # approach improved by OP -> monospace!
plt.axis('off')
plt.tight_layout()
plt.savefig('image/sarima_summary')

# %%
res = sarima.resid
fig,ax = plt.subplots(2,1,figsize=(15,8))
fig = sm.graphics.tsa.plot_acf(res, lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, lags=50, ax=ax[1])
plt.show()

# %%
pred = sarima.predict()

# %%
pd.DataFrame({'actual':ts_tipping,'prediction':pred}).plot()
plt.show()
# Out:
# /Users/kmiyaki/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)

# %%
sarima.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
import itertools
# Define the p, d and q parameters to take any value between 0 and 5
p = d = q = range(0, 3)

# Generate all different combinations of p, q and q triplets
pdq = [4, 1, 2]

# Generate all different combinations of seasonal p, q and q triplets
pdqs = [(x[0], x[1], x[2], 24) for x in list(itertools.product(p, d, q))]

# %%
# Run a grid with pdq and seasonal pdq parameters calculated above and get the best AIC value
ans = []

for combs in pdqs:
    try:
        mod = sm.tsa.statespace.SARIMAX(ts_tipping,
                                        order=pdq,
                                        seasonal_order=combs,
                                        enforce_stationarity=False,
                                        enforce_invertibility=False)

        output = mod.fit()
        ans.append([pdq, combs, output.aic])
        print('SARIMA {} x {} : AIC Calculated ={}'.format(pdq, combs, output.aic))
    except:
        continue

# %%
# # Find the parameters with minimal AIC value.
# ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
# ans_df.loc[ans_df['aic'].idxmin()]
